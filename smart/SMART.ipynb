# %%
import pandas as pd

# %%
df = pd.read_csv("smart.csv")
df = df.dropna(axis='columns')
df = df.set_index('Day')
display(df)
# Out:
#      [4, 4, 4, 3, 3, 3]  [4, 4, 4, 4, 3, 2]  [4, 4, 4, 4, 4, 1]  \
# Day
# 1                    19                   2                   2
# 2                    50                   2                   2
# 3                    53                   4                  48
# 4                    37                   4                  92
# 5                    21                   2                  57
# ..                  ...                 ...                 ...
# 192                  43                   0                   2
# 193                  82                   0                   2
# 194                  49                   0                   1
# 195                  81                   0                   0
# 196                  48                   0                   0
#
#      [5, 4, 3, 3, 3, 3]  [5, 4, 4, 3, 3, 2]  [5, 4, 4, 4, 2, 2]  \
# Day
# 1                     2                   2                   2
# 2                     2                   2                   2
# 3                     2                   2                   2
# 4                     2                   2                   2
# 5                     2                   2                   2
# ..                  ...                 ...                 ...
# 192                   0                   0                   0
# 193                   0                   0                   0
# 194                   0                   0                   0
# 195                   0                   0                   0
# 196                   0                   0                   0
#
#      [5, 4, 4, 4, 3, 1]  [5, 4, 4, 4, 4, 0]  [5, 5, 3, 3, 3, 2]  \
# Day
# 1                     2                   2                   2
# 2                     2                   2                   2
# 3                     2                   2                   2
# 4                     2                   2                   2
# 5                     2                   2                   2
# ..                  ...                 ...                 ...
# 192                   0                  64                   0
# 193                   0                 128                   0
# 194                   0                  75                   0
# 195                   0                 108                   0
# 196                   0                  93                   0
#
#      [5, 5, 4, 3, 2, 2]  ...  [17, 2, 2, 0, 0, 0]  [17, 3, 1, 0, 0, 0]  \
# Day                      ...
# 1                     2  ...                    2                    1
# 2                     2  ...                    2                    1
# 3                     1  ...                    2                    0
# 4                     1  ...                    2                    0
# 5                     0  ...                    2                    0
# ..                  ...  ...                  ...                  ...
# 192                   0  ...                    0                    0
# 193                   0  ...                    0                    0
# 194                   0  ...                    0                    0
# 195                   0  ...                    0                    0
# 196                   0  ...                    0                    0
#
#      [17, 4, 0, 0, 0, 0]  [18, 1, 1, 1, 0, 0]  [18, 2, 1, 0, 0, 0]  \
# Day
# 1                      2                    2                    2
# 2                      1                    1                    2
# 3                      1                    1                    1
# 4                      1                    1                    0
# 5                      0                    1                    0
# ..                   ...                  ...                  ...
# 192                    0                    0                    0
# 193                    0                    0                    0
# 194                    0                    0                    0
# 195                    0                    0                    0
# 196                    0                    0                    0
#
#      [18, 3, 0, 0, 0, 0]  [19, 1, 1, 0, 0, 0]  [19, 2, 0, 0, 0, 0]  \
# Day
# 1                      2                    2                    2
# 2                      2                    2                    2
# 3                      2                    2                    1
# 4                      2                    1                    0
# 5                      2                    0                    0
# ..                   ...                  ...                  ...
# 192                    0                    0                    0
# 193                    0                    0                    0
# 194                    0                    0                    0
# 195                    0                    0                    0
# 196                    0                    0                    0
#
#      [20, 1, 0, 0, 0, 0]  [21, 0, 0, 0, 0, 0]
# Day
# 1                      2                    1
# 2                      2                    0
# 3                      1                    0
# 4                      0                    0
# 5                      0                    0
# ..                   ...                  ...
# 192                    0                    0
# 193                    0                    0
# 194                    0                    0
# 195                    0                    0
# 196                    0                    0
#
# [196 rows x 331 columns]

# %%
df.plot(figsize = [20,30])

# %%
df_mean = df.mean()

# %%
df_max = df.max()

# %%
df_best = df.T.idxmax()

# %%
df_bestValues = df_best.value_counts()

# %%
df_bestValues.to_csv("best.csv")
# Out:
# C:\Users\Sergio\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
filtered.plot(figsize=[900,10],ylim=[10,30])

# %%
filtered.plot(figsize=[900,10],ylim=[10,30])

# %%
filtered.plot(figsize=[950,10],ylim=[10,30])

# %%
df[df.columns[0]].plot(figsize=[300,10])

# %%
df_best
# Out:
# Day
# 0      [4, 4, 4, 3, 3, 3]
# 1      [4, 4, 4, 3, 3, 3]
# 2      [4, 4, 4, 3, 3, 3]
# 3      [4, 4, 4, 3, 3, 3]
# 4      [4, 4, 4, 3, 3, 3]
#               ...
# 195    [6, 6, 6, 1, 1, 1]
# 196    [6, 6, 6, 1, 1, 1]
# 197    [6, 6, 6, 1, 1, 1]
# 198    [6, 6, 6, 1, 1, 1]
# 199    [6, 6, 6, 1, 1, 1]
# Length: 200, dtype: object
