# %%
import pandas as pd

# %%
df = pd.read_csv("SimulationData.csv",delimiter = "\t")
df = df.dropna(axis='columns')
df = df.set_index('Day')
display(df)
# Out:
#            [4, 4, 4, 3, 3, 3]  [4, 4, 4, 4, 3, 2]  [4, 4, 4, 4, 4, 1]  \
# Day
# 0                           2                   4                   1
# 1000                        9                  12                   9
# 2000                        6                   7                   7
# 3000                        1                   3                   6
# 4000                        1                   1                   2
# ...                       ...                 ...                 ...
# 149995000                   0                   0                   0
# 149996000                   0                   0                   0
# 149997000                   0                   1                   0
# 149998000                   0                   0                   0
# 149999000                   0                   0                   0
#
#            [5, 4, 3, 3, 3, 3]  [5, 4, 4, 3, 3, 2]  [5, 4, 4, 4, 2, 2]  \
# Day
# ...

# %%
# df_max = df.cummax()
# df_max = df_max.drop(range(499))
# df_max.rename(index)

# df_diff = df.diff()

display(df)
# Out:
#            [4, 4, 4, 3, 3, 3]  [4, 4, 4, 4, 3, 2]  [4, 4, 4, 4, 4, 1]  \
# Day
# 0                           2                   4                   1
# 1000                        9                  12                   9
# 2000                        6                   7                   7
# 3000                        1                   3                   6
# 4000                        1                   1                   2
# ...                       ...                 ...                 ...
# 149995000                   0                   0                   0
# 149996000                   0                   0                   0
# 149997000                   0                   1                   0
# 149998000                   0                   0                   0
# 149999000                   0                   0                   0
#
#            [5, 4, 3, 3, 3, 3]  [5, 4, 4, 3, 3, 2]  [5, 4, 4, 4, 2, 2]  \
# Day
# ...

# %%
limit = 15

col = df.columns[df.max() > limit]

# %%
filtered = df[col]

# %%
size = 10000000
for i in range(10):
    filtered.plot(figsize=[30,20],xlim=[i*size,(i+1)*size],ylim=[10,30])

# %%
df_mean = df.mean()

# %%
df_max = df.max()

# %%
df_best = df.T.idxmax()

# %%
df_bestValues = df_best.value_counts()

# %%
df_bestValues.to_csv("bestValues.csv")

# %%
filtered.plot(figsize=[900,10],ylim=[10,30])

# %%
filtered.plot(figsize=[900,10],ylim=[10,30])

# %%
filtered.plot(figsize=[950,10],ylim=[10,30])

# %%
df[df.columns[0]].plot(figsize=[300,10])
